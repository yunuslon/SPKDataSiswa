# %%
import os,django
import pandas as pd
from orm.models import Siswa,Kelas,Karakter,HasilTes,NilaiAkademik,Plomba,TesOlimpiade,Bobot
import math
from django.contrib.auth.models import User

# %%
tp =TesOlimpiade.objects.all()
sw = Siswa.objects.all()
user = User.objects.all()
ht = HasilTes.objects.all()

# %%
def ListDatauser(user):
    us=User.objects.all()
    if len(us)>0:
        cols = ['id']
        dt ={
            cols[0] : [str(a.username) for a in us],
            
        }
        dfdata_siswa = pd.DataFrame(data=dt)
        return dfdata_siswa
    else:
        return[]
ListDatauser(user)
# Out:
#                     id
# 0       gora@gmail.com
# 1     sagita@gmail.com
# 2     satria@gmail.com
# 3      azura@gmail.com
# 4    afriani@gmail.com
# 5       reza@gmail.com
# 6        dio@gmail.com
# 7      desak@gmail.com
# 8    binazir@gmail.com
# 9       made@gmail.com
# 10              admin1
# 11  yunuslon@gmail.com

# %%
def ListDataSiswa(sw):
    if len(sw)>0:
        cols = ['id','username','siswa','alamat','mata_pelajaran','nilai_akademik','jenjang',
               'sikap','intensitas']
        
        dt ={
            cols[0] : [int(a.id) for a in sw],
            cols[1] : [str(a.user)  for a in sw],
            cols[2] : [str(a.nama) for a in sw],
            cols[3] : [str(a.alamat) for a in sw],
            cols[4] : [str(a.nilai_akademiks.mata_pelajaran) for a in sw],
            cols[5] : [int(a.nilai_akademiks.nilai) for a in sw],
            cols[6] : [str(a.kelass.jenjang) for a in sw],
            cols[7] : [str(a.karakters.sikap) for a in sw],
            cols[8] : [str(a.plombas.intensitas) for a in sw],
        }
        dfdata_siswa = pd.DataFrame(data=dt)
        return dfdata_siswa
    else:
        return[]

def ListDatauser(user):
    us=User.objects.all()
    if len(us)>0:
        cols = ['id']
        dt ={
            cols[0] : [str(a.username) for a in us],
            
        }
        dfdata_siswa = pd.DataFrame(data=dt)
        return dfdata_siswa
    else:
        return[]
ListDataSiswa(sw)
# Out:
#    id           username                  siswa           alamat  \
# 0   2     gora@gmail.com             Gora Wahyu       Taman Baru
# 1   3   sagita@gmail.com           Sagita Putri   Pabutan Permai
# 2   4   satria@gmail.com            Satria Wira           Moncok
# 3  12    azura@gmail.com        Azura fransisca         Perumnas
# 4  13  afriani@gmail.com  Afriani Ibrahim Putri       Taman sari
# 5  14     reza@gmail.com          Reza Rahmanto    Pondok Perasi
# 6  15      dio@gmail.com       Oktadio Erikardo       Taman Baru
# 7  16    desak@gmail.com   I Desak Puspita Sari           Gebang
# 8  17  binazir@gmail.com         Binazir silvia  Pejeruk Bangket
# 9  18     made@gmail.com        I MadeRandiawan           Monjok
#
#   mata_pelajaran  nilai_akademik jenjang       sikap  \
# 0        biologi              90   2 SMA        Baik
# 1        biologi              90   3 SMA        Baik
# 2        biologi              90   3 SMA        Baik
# 3        biologi              87   1 SMA  Cukup Baik
# 4        biologi              88   2 SMA        Baik
# 5         fisika              90   2 SMA        Baik
# 6         fisika              87   3 SMA        Baik
# 7         fisika              89   1 SMA        Baik
# 8         fisika              86   3 SMA  Cukup Baik
# 9         fisika              90   2 SMA  Cukup Baik
#
#                          intensitas
# 0        Sering Mengikuti Olimpiade
# 1        Sering Mengikuti Olimpiade
# 2        Sering Mengikuti Olimpiade
# 3  Cukup Sering Mengikuti Olimpiade
# 4        Sering Mengikuti Olimpiade
# 5        Sering Mengikuti Olimpiade
# 6  Cukup Sering Mengikuti Olimpiade
# 7  Cukup Sering Mengikuti Olimpiade
# 8  Cukup Sering Mengikuti Olimpiade
# 9        Jarang Mengikuti Olimpiade

# %%
def SlkIdBio(sw):
    c= ListDataSiswa(sw)
    tmpA=list(zip(c.mata_pelajaran,c.username))
    tmp=[]
    for i in range(len(c)):
        if tmpA[i][0] == "biologi":
            tmp.append(tmpA[i][1])
    df=pd.DataFrame(data=tmp,columns=['Username'])
    return df
SlkIdBio(sw)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0a8f6dbe8786> in <module>()
#       8     df=pd.DataFrame(data=tmp,columns=['Username'])
#       9     return df
# ---> 10 SlkIdBio(sw)
#
# <ipython-input-12-0a8f6dbe8786> in SlkIdBio(sw)
#       1 def SlkIdBio(sw):
# ----> 2     c= ListDataSiswa(sw)
#       3     tmpA=list(zip(c.mata_pelajaran,c.username))
#       4     tmp=[]
#       5     for i in range(len(c)):
#
# <ipython-input-11-dc79bd453cfb> in ListDataSiswa(sw)
#       6         dt ={
#       7             cols[0] : [int(a.id) for a in sw],
# ----> 8             cols[1] : [str(a.user_password)  for a in sw],
#       9             cols[2] : [str(a.nama) for a in sw],
#      10             cols[3] : [str(a.alamat) for a in sw],
#
# <ipython-input-11-dc79bd453cfb> in <listcomp>(.0)
#       6         dt ={
#       7             cols[0] : [int(a.id) for a in sw],
# ----> 8             cols[1] : [str(a.user_password)  for a in sw],
#       9             cols[2] : [str(a.nama) for a in sw],
#      10             cols[3] : [str(a.alamat) for a in sw],
#
# AttributeError: 'Siswa' object has no attribute 'user_password'

# %%
def ListTesOlimpiade(tp):
    if len(tp)>0:
        cols = ['mata_pelajaran','no','gambar','pertayaan',
                'jawabanA','jawabanB','jawabanC','jawabanD','jawabanE','kunci','id']
        
        topd ={
            cols[0] : [str(a.mata_pelajaran) for a in tp],
            cols[1] : [int(a.no) for a in tp],
            cols[2] : [str(a.gambar) for a in tp],
            cols[3] : [str(a.pertayaan) for a in tp],
            cols[4] : [str(a.jawabanA) for a in tp],
            cols[5] : [str(a.jawabanB) for a in tp],
            cols[6] : [str(a.jawabanC) for a in tp],
            cols[7] : [str(a.jawabanD) for a in tp],
            cols[8] : [str(a.jawabanE) for a in tp],
            cols[9] : [str(a.kunci) for a in tp],
            cols[10] : [str(a.id) for a in tp],
        }
        dfmt = pd.DataFrame(data=topd)
        return dfmt
    else:
        return[]

# %%
def soal_id_bio(tp):
    c= ListTesOlimpiade(tp)
    tmpA=list(zip(c.mata_pelajaran,c.no,c.gambar,c.pertayaan,
                  c.jawabanA,c.jawabanB,c.jawabanC,c.jawabanD,c.jawabanE,c.kunci,c.id))
    tmp=[]
    for i in range(len(c)):
        if tmpA[i][0] == "biologi":
            tmp.append(tmpA[i][10])
    df=pd.DataFrame(data=tmp, columns=['ID'])
    return df

# %%
def SleksiSoalBio():
    c= ListTesOlimpiade(tp)
    tmpA=list(zip(c.mata_pelajaran,c.no,c.gambar,c.pertayaan,
                  c.jawabanA,c.jawabanB,c.jawabanC,c.jawabanD,c.jawabanE,c.kunci,c.id))
    def id_soal():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][10])
        df=pd.DataFrame(data=tmp, columns=['id'])
        return df
    
    def no():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][1])
        df=pd.DataFrame(data=tmp, columns=['No'])
        return df

    def gambar():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][2])
        df=pd.DataFrame(data=tmp, columns=['Gambar'])
        return df
    
    def pertayaan():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][3])
        df=pd.DataFrame(data=tmp, columns=['Pertayaan'])
        return df

    def jawabanA():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][4])
        df=pd.DataFrame(data=tmp, columns=['JawabanA'])
        return df

    def jawabanB():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][5])
        df=pd.DataFrame(data=tmp, columns=['JawabanB'])
        return df

    def jawabanC():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][6])
        df=pd.DataFrame(data=tmp, columns=['JawabanC'])
        return df

    def jawabanD():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][7])
        df=pd.DataFrame(data=tmp, columns=['JawabanD'])
        return df

    def jawabanE():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][8])
        df=pd.DataFrame(data=tmp, columns=['JawabanE'])
        return df
    
    def kunci():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "biologi":
                tmp.append(tmpA[i][9])
        df=pd.DataFrame(data=tmp, columns=['Kunci'])
        return df
    
    gabung= pd.concat([id_soal(),no(),gambar(),pertayaan(),jawabanA(),jawabanB(),jawabanC(),jawabanD(),jawabanE(),kunci()],
                      axis=1)

    return gabung

SleksiSoalBio()
# Out:
#   id  No                              Gambar  \
# 0  1   1               ../media/gambar/a.png
# 1  2   2               ../media/gambar/a.png
# 2  3   3                     gambar/urin.png
# 3  4   4  gambar/Pertumbuhanperkembangan.png
# 4  5   5               ../media/gambar/a.png
#
#                                            Pertayaan  \
# 0  Berikut ini adalah ciri yang dimiliki fauna kh...
# 1  Penggolongan organisme dengan menggunakan klas...
# 2  Salah satu proses pembentukan urin, terjadi pr...
# 3  Dua kecambah kacang hijau diletakkan di suatu ...
# 4  Molekul tRNA merupakan jenis RNA yang terdapat...
#
#                                             JawabanA  \
# 0                    banyak Mammalia berukuran besar
# 1                                            habitat
# 2                                                  1
# 3  cahaya merupakan faktor yang tidak dibutuhkan ...
# 4  membentuk pita tunggal RNA yang akan ditranskr...
#
#                                           JawabanB  \
# 0             terdapat berbagai macam spesies kera
# 1                            habitat dan morfologi
# 2                                                2
# 3     pertumbuhan kecambah tidak memerlukan cahaya
# 4  mengirimkan informasi genetik ke dalam ribosom.
#
#                                            JawabanC  \
# 0      terdapat berbagai macam burung berbulu indah
# 1                            ciri bentuk luar tubuh
# 2                                                 3
# 3  cahaya sangat mempengaruhi pertumbuhan kecambah.
# 4               membawa asam amino hasil translasi.
#
#                                             JawabanD  \
# 0                           sedikit hewan berkantung
# 1                         kekerabatan secara evolusi
# 2                                                  4
# 3  cahaya diperlukan dalam jumlah sedikit untuk p...
# 4       menerjemahkan asam amino yang akan dibentuk.
#
#                                         JawabanE Kunci
# 0                           banyak hewan primata     C
# 1                            habitus (perawakan)     C
# 2                                              5     D
# 3  cahaya dapat menghambat pertumbuhan kecambah.     E
# 4          membantu DNA untuk mensintesis kodon.     C

# %%
def SleksiSoalFis():
    c= ListTesOlimpiade(tp)
    tmpA=list(zip(c.mata_pelajaran,c.no,c.gambar,c.pertayaan,
                  c.jawabanA,c.jawabanB,c.jawabanC,c.jawabanD,c.jawabanE,c.kunci))
    def no():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][1])
        df=pd.DataFrame(data=tmp, columns=['No'])
        return df

    def gambar():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][2])
        df=pd.DataFrame(data=tmp, columns=['Gambar'])
        return df
    
    def pertayaan():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][3])
        df=pd.DataFrame(data=tmp, columns=['Pertayaan'])
        return df

    def jawabanA():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][4])
        df=pd.DataFrame(data=tmp, columns=['JawabanA'])
        return df

    def jawabanB():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][5])
        df=pd.DataFrame(data=tmp, columns=['JawabanB'])
        return df

    def jawabanC():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][6])
        df=pd.DataFrame(data=tmp, columns=['JawabanC'])
        return df

    def jawabanD():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][7])
        df=pd.DataFrame(data=tmp, columns=['JawabanD'])
        return df

    def jawabanE():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][8])
        df=pd.DataFrame(data=tmp, columns=['JawabanE'])
        return df
    
    def kunci():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "fisika":
                tmp.append(tmpA[i][9])
        df=pd.DataFrame(data=tmp, columns=['Kunci'])
        return df
    
    gabung= pd.concat([no(),gambar(),pertayaan(),jawabanA(),jawabanB(),jawabanC(),jawabanD(),jawabanE(),kunci()],
                      axis=1)

    return gabung

# %%
def SleksiSoalKim():
    c= ListTesOlimpiade(tp)
    tmpA=list(zip(c.mata_pelajaran,c.no,c.gambar,c.pertayaan,
                  c.jawabanA,c.jawabanB,c.jawabanC,c.jawabanD,c.jawabanE,c.kunci))
    def no():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][1])
        df=pd.DataFrame(data=tmp, columns=['No'])
        return df

    def gambar():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][2])
        df=pd.DataFrame(data=tmp, columns=['Gambar'])
        return df
    
    def pertayaan():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][3])
        df=pd.DataFrame(data=tmp, columns=['Pertayaan'])
        return df

    def jawabanA():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][4])
        df=pd.DataFrame(data=tmp, columns=['JawabanA'])
        return df

    def jawabanB():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][5])
        df=pd.DataFrame(data=tmp, columns=['JawabanB'])
        return df

    def jawabanC():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][6])
        df=pd.DataFrame(data=tmp, columns=['JawabanC'])
        return df

    def jawabanD():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][7])
        df=pd.DataFrame(data=tmp, columns=['JawabanD'])
        return df

    def jawabanE():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][8])
        df=pd.DataFrame(data=tmp, columns=['JawabanE'])
        return df
    
    def kunci():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "kimia":
                tmp.append(tmpA[i][9])
        df=pd.DataFrame(data=tmp, columns=['Kunci'])
        return df
    
    gabung= pd.concat([no(),gambar(),pertayaan(),jawabanA(),jawabanB(),jawabanC(),jawabanD(),jawabanE(),kunci()],
                      axis=1)

    return gabung

# %%
def SleksiSoalMat():
    c= ListTesOlimpiade(tp)
    tmpA=list(zip(c.mata_pelajaran,c.no,c.gambar,c.pertayaan,
                  c.jawabanA,c.jawabanB,c.jawabanC,c.jawabanD,c.jawabanE,c.kunci))
    def no():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][1])
        df=pd.DataFrame(data=tmp, columns=['No'])
        return df

    def gambar():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][2])
        df=pd.DataFrame(data=tmp, columns=['Gambar'])
        return df
    
    def pertayaan():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][3])
        df=pd.DataFrame(data=tmp, columns=['Pertayaan'])
        return df

    def jawabanA():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][4])
        df=pd.DataFrame(data=tmp, columns=['JawabanA'])
        return df

    def jawabanB():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][5])
        df=pd.DataFrame(data=tmp, columns=['JawabanB'])
        return df

    def jawabanC():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][6])
        df=pd.DataFrame(data=tmp, columns=['JawabanC'])
        return df

    def jawabanD():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][7])
        df=pd.DataFrame(data=tmp, columns=['JawabanD'])
        return df

    def jawabanE():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][8])
        df=pd.DataFrame(data=tmp, columns=['JawabanE'])
        return df
    
    def kunci():
        tmp=[]
        for i in range(len(c)):
            if tmpA[i][0] == "matematika":
                tmp.append(tmpA[i][9])
        df=pd.DataFrame(data=tmp, columns=['Kunci'])
        return df
    
    gabung= pd.concat([no(),gambar(),pertayaan(),jawabanA(),jawabanB(),jawabanC(),jawabanD(),jawabanE(),kunci()],
                      axis=1)

    return gabung
